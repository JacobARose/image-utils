# %% [markdown]
# ## Matplotlib Legend placement playground

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create some sample data
data = np.arange(20)
# Create a matplotlib figure
fig, ax = plt.subplots()
# Create multiple plots 
for i in range(7):
    ax.plot(data, i * data, label=f'y={i}x')
# Set title and labels
ax.set_title('Example plot')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Add a legend
ax.legend()
# Visualize the final plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create some sample data
data = np.arange(20)
# Create a matplotlib figure
fig, ax = plt.subplots()
# Create multiple plots 
for i in range(7):
    ax.plot(data, i * data, label=f'y={i}x')
# Set title and labels
ax.set_title('Example plot')
ax.set_xlabel('x')
ax.set_ylabel('y')

# Add a legend
pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width * 0.9, pos.height])
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5))
# Visualize the final plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create some sample data
data = np.arange(20)
# Create a matplotlib figure
fig, ax = plt.subplots(figsize=(10,7))
# Create multiple plots 
for i in range(7):
    ax.plot(data, i * data, label=f'y={i}x')
# Set title and labels
ax.set_title('Example plot')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Add a legend
pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.65])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
# Visualize the final plot
plt.show()

# %%
# !pip install empiricaldist
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting empiricaldist
#   Downloading empiricaldist-0.6.3.tar.gz (9.3 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: empiricaldist
#   Building wheel for empiricaldist (setup.py) ... done
#   Created wheel for empiricaldist: filename=empiricaldist-0.6.3-py3-none-any.whl size=10545 sha256=1c6133b13a15f27afb6e7e6209932849a5ddbb8130ec9c1a932497f9caeedb96
#   Stored in directory: /tmp/pip-ephem-wheel-cache-is4yfges/wheels/f4/48/c1/603790e9696a1e2dd56c1e2a306d47379f02d8c75750645f02
# Successfully built empiricaldist
# Installing collected packages: empiricaldist
# Successfully installed empiricaldist-0.6.3

# %%
from empiricaldist import Pmf  # pip install empiricaldist

# Compute PMF
pmf_dist = Pmf.from_seq(x, normalize=False)
